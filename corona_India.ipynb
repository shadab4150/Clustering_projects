# %% [markdown]
# <a href="https://colab.research.google.com/github/shadab4150/practice_projects/blob/master/corona_India.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip 'corona-virus-report (2).zip'
# Out:
# Archive:  corona-virus-report (2).zip
#   inflating: covid_19_clean_complete.csv

# %%
# !unzip /content/covid19-corona-virus-india-dataset.zip
# Out:
# Archive:  /content/covid19-corona-virus-india-dataset.zip
#   inflating: complete.csv
#   inflating: web_scraping.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as immg
import numpy as np
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
india = pd.read_csv('/content/complete.csv')
india.head()
# Out:
#          Date Name of State / UT  ...  Longitude  Death
# 0  2020-01-30             Kerala  ...    76.2711      0
# 1  2020-01-31             Kerala  ...    76.2711      0
# 2  2020-02-01             Kerala  ...    76.2711      0
# 3  2020-02-02             Kerala  ...    76.2711      0
# 4  2020-02-03             Kerala  ...    76.2711      0
#
# [5 rows x 8 columns]

# %%
df = pd.read_csv('covid_19_clean_complete.csv')

# %%
cur = df[df['Date']=='3/20/20'].copy()

# %%
df.tail()
# Out:
#       Province/State    Country/Region      Lat  ...  Confirmed Deaths  Recovered
# 16869   Sint Maarten       Netherlands  18.0425  ...          1      0          0
# 16870            NaN             Niger  17.6078  ...          1      0          0
# 16871            NaN  Papua New Guinea  -6.3150  ...          1      0          0
# 16872    Isle of Man    United Kingdom  54.2361  ...          1      0          0
# 16873            NaN          Zimbabwe -20.0000  ...          1      0          0
#
# [5 rows x 8 columns]

# %%
ind = df[df['Country/Region']=='India'].copy()
us = df[df['Country/Region']=='US'].copy()
china = df[df['Country/Region']=='China'].copy()

# %%
china.head()
# Out:
#     Province/State Country/Region      Lat  ...  Confirmed Deaths  Recovered
# 154          Hubei          China  30.9756  ...        444     17         28
# 158      Guangdong          China  23.3417  ...         26      0          0
# 159          Henan          China  33.8820  ...          5      0          0
# 160       Zhejiang          China  29.1832  ...         10      0          0
# 161          Hunan          China  27.6104  ...          4      0          0
#
# [5 rows x 8 columns]

# %%
plt.figure(1,figsize=(20,8))
plt.plot(ind.Confirmed.values)
plt.title("India Commulative cases growth each day ")
plt.xticks(np.arange(ind.shape[0]),ind.Date.values.tolist(),rotation=90);

# %%
grow = []
val = [0]+ind.Confirmed.values.tolist()
for i in range(len(val)-1):
  a = abs(val[i+1]-val[i])
  grow.append(a)

# %%
plt.figure(1,figsize=(20,8))
sns.barplot(x=ind.Date[-20:],y=ind.Confirmed[-20:],color='skyblue',label='Total Confirmed cases that Day ');
sns.barplot(x=ind.Date[-20:],y=grow[-20:],color='red',label='New Cases That Day');
plt.title("Total Confirmed cases vs New Cases per Day from previous 20 days")
plt.legend()
#plt.xticks(np.arange(ind.shape[0])[-7:],ind.Date.values.tolist()[-7:],rotation=90);

# %%
plt.figure(1,figsize=(20,8))
#sns.barplot(x=ind.Date[-20:],y=ind.Confirmed[-20:],color='skyblue',label='Total Confirmed cases that Day ');
sns.barplot(x=ind.Date[-20:],y=grow[-20:],color='red',label='New Cases That Day');
plt.title("Growth in  New Cases per Day from previous 20 days")
plt.legend()

# %%
india.dtypes
# Out:
# Date                                           object
# State                                          object
# Confirmed cases (Indian National)               int64
# Total Confirmed cases ( Foreign National )      int64
# Cured/Discharged/Migrated                       int64
# Latitude                                      float64
# Longitude                                     float64
# Death                                           int64
# dtype: object

# %%
st =india[india['Date']=='2020-03-20']
plt.figure(1,figsize=(20,8))
sns.barplot(data=st,x='State',y='Confirmed cases (Indian National)')
plt.title('India Cases State wise')
plt.xticks(np.arange(st.shape[0]),st.State.values.tolist(),rotation=90);

# %%
plt.figure(1,figsize=(22,8))
color = list(repeatlist(color, 31))
squarify.plot(sizes=st['Confirmed cases (Indian National)'].values.tolist(),
              label=st.State.values.tolist(), alpha=.7,color=color,
              )
plt.axis('off')
plt.title('Number of confirmed cases in India')
plt.show()

# %%
india.columns = ['Date', 'State', 'Confirmed cases (Indian National)',
       'Total Confirmed cases ( Foreign National )',
       'Cured/Discharged/Migrated', 'Latitude', 'Longitude', 'Death']

# %%
fig = px.scatter_geo(india[india['Date']=='2020-03-20'], lat='Latitude',lon="Longitude", hover_name="State",color='State',size='Confirmed cases (Indian National)',animation_frame='Date', projection="natural earth",scope='asia',height=1080,width=1980)
fig.show()

# %% [markdown]
# ![kd](https://i.ibb.co/RN1g5vB/newplot26.png)

# %% [markdown]
# <center><h1> USA </h1></center>

# %%
us.head()
# Out:
#        Province/State Country/Region      Lat  ...  Confirmed Deaths  Recovered
# 98         Washington             US  47.4009  ...          0      0          0
# 99           New York             US  42.1657  ...          0      0          0
# 100        California             US  36.1162  ...          0      0          0
# 101     Massachusetts             US  42.2302  ...          0      0          0
# 102  Diamond Princess             US  35.4437  ...          0      0          0
#
# [5 rows x 8 columns]

# %%
plt.figure(1,figsize=(20,8))
sns.barplot(data=us[us['Date']=='3/20/20'],x='Province/State',y='Confirmed');
plt.xticks(np.arange(us[us['Date']=='3/20/20'].shape[0]),us[us['Date']=='3/20/20']['Province/State'].values.tolist(),rotation=90);

# %%
usa  = us[us['Date']=='3/19/20'].copy();usa.head()
# Out:
#          Province/State Country/Region      Lat  ...  Confirmed Deaths  Recovered
# 15887        Washington             US  47.4009  ...       1376     74          0
# 15888          New York             US  42.1657  ...       5365     34          0
# 15889        California             US  36.1162  ...        952     18          0
# 15890     Massachusetts             US  42.2302  ...        328      0          0
# 15891  Diamond Princess             US  35.4437  ...         47      0          0
#
# [5 rows x 8 columns]

# %%
fig = px.scatter_geo(us, lat='Lat',lon="Long", hover_name="Province/State",color='Province/State',size='Confirmed',animation_frame='Date', projection="albers usa")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="877fa9ab-fd38-4531-89ce-a4f1dc9856fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("877fa9ab-fd38-4531-89ce-a4f1dc9856fc")) {
#                     Plotly.newPlot(
#                         '877fa9ab-fd38-4531-89ce-a4f1dc9856fc',
# ...

# %%
fig1 = px.scatter_geo(df, lat='Lat',lon="Long", hover_name="Province/State",animation_frame='Date',
                      color='Confirmed',size='Confirmed' ,projection="natural earth")
fig1.show()

# %%
from itertools import cycle, islice


def repeatlist(it, count):
    return islice(cycle(it), count)
color = ['r', 'g', 'b','c','m','y','gold','orange','skyblue','pink','cyan','lime','olive','purple']

# %%
# !pip install squarify

# %%
import squarify

# %%
plt.figure(1,figsize=(22,8))
color = list(repeatlist(color, 31))
squarify.plot(sizes=cur[(cur['Confirmed']>15)&(cur['Country/Region']=='US')].Confirmed.values.tolist(),
              label=cur[(cur['Confirmed']>15)&(cur['Country/Region']=='US')]['Province/State'].values.tolist(), alpha=.7,color=color,
              )
plt.axis('off')
plt.title('Number of confirmed cases in USA')
plt.show()
